# %% [markdown]
# # Load packages

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data preparation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read data 

import pandas as pd
from google.colab import drive
df = pd.read_csv('/content/sample_data/House_Rent_Dataset.csv')
print(df)
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4741              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner
#
# [4746 rows x 12 columns]

# %%
# Check data teratas

df.head(10)
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
# 5  2022-04-29    2   7000   600  Ground out of 1   Super Area
# 6  2022-06-21    2  10000   700  Ground out of 4   Super Area
# 7  2022-06-21    1   5000   250       1 out of 2   Super Area
# 8  2022-06-07    2  26000   800       1 out of 2  Carpet Area
# 9  2022-06-20    2  10000  1000       1 out of 3  Carpet Area
#
#                      Area Locality     City Furnishing Status  \
# 0                           Bandel  Kolkata       Unfurnished
# 1         Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished
# 2          Salt Lake City Sector 2  Kolkata    Semi-Furnished
# 3                      Dumdum Park  Kolkata       Unfurnished
# 4                    South Dum Dum  Kolkata       Unfurnished
# 5                      Thakurpukur  Kolkata       Unfurnished
# 6                         Malancha  Kolkata       Unfurnished
# 7                         Malancha  Kolkata       Unfurnished
# 8  Palm Avenue Kolkata, Ballygunge  Kolkata       Unfurnished
# 9                         Natunhat  Kolkata    Semi-Furnished
#
#    Tenant Preferred  Bathroom Point of Contact
# 0  Bachelors/Family         2    Contact Owner
# 1  Bachelors/Family         1    Contact Owner
# 2  Bachelors/Family         1    Contact Owner
# 3  Bachelors/Family         1    Contact Owner
# 4         Bachelors         1    Contact Owner
# 5  Bachelors/Family         2    Contact Owner
# 6         Bachelors         2    Contact Agent
# 7         Bachelors         1    Contact Agent
# 8         Bachelors         2    Contact Agent
# 9  Bachelors/Family         2    Contact Owner

# %%
# Check row and column

df.shape
# Out:
# (4746, 12)

# %%
df.tail()
# Out:
#        Posted On  BHK   Rent  Size         Floor    Area Type  \
# 4741  2022-05-18    2  15000  1000    3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000    1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750    3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500  23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000    4 out of 5  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 4741          Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742  Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743  Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744            Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745       Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner

# %%
df.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
df.nunique()
# Out:
# Posted On              81
# BHK                     6
# Rent                  243
# Size                  615
# Floor                 480
# Area Type               3
# Area Locality        2235
# City                    6
# Furnishing Status       3
# Tenant Preferred        3
# Bathroom                8
# Point of Contact        3
# dtype: int64

# %%
df_new = df.drop(['Posted On', 'BHK', 'Rent'], axis = 1)
df_new.head()
# Out:
#    Size            Floor    Area Type             Area Locality     City  \
# 0  1100  Ground out of 2   Super Area                    Bandel  Kolkata
# 1   800       1 out of 3   Super Area  Phool Bagan, Kankurgachi  Kolkata
# 2  1000       1 out of 3   Super Area   Salt Lake City Sector 2  Kolkata
# 3   800       1 out of 2   Super Area               Dumdum Park  Kolkata
# 4   850       1 out of 2  Carpet Area             South Dum Dum  Kolkata
#
#   Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# 0       Unfurnished  Bachelors/Family         2    Contact Owner
# 1    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 2    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 3       Unfurnished  Bachelors/Family         1    Contact Owner
# 4       Unfurnished         Bachelors         1    Contact Owner

# %%
df_new['Area Type'].unique()
# Out:
# array(['Super Area', 'Carpet Area', 'Built Area'], dtype=object)

# %%
df_new['Area Type'].value_counts()
# Out:
# Super Area     2446
# Carpet Area    2298
# Built Area        2
# Name: Area Type, dtype: int64

# %%
import plotly.express as px
fig1 = px.histogram(df_new, x = 'Area Type', color = 'Area Type')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="86b8434c-7fdd-4a12-a241-b11b7529c89d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86b8434c-7fdd-4a12-a241-b11b7529c89d")) {                    Plotly.newPlot(                        "86b8434c-7fdd-4a12-a241-b11b7529c89d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Area Type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Super Area","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Super Area","offsetgroup":"Super Area","orientation":"v","showlegend":true,"x":["Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area","Super Area" ...

# %% [markdown]
# ### Summary Area Locality

# %%
df_new = df.drop(['Area Locality', 'City', 'Furnishing Status'], axis = 1)
df_new.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#    Tenant Preferred  Bathroom Point of Contact
# 0  Bachelors/Family         2    Contact Owner
# 1  Bachelors/Family         1    Contact Owner
# 2  Bachelors/Family         1    Contact Owner
# 3  Bachelors/Family         1    Contact Owner
# 4         Bachelors         1    Contact Owner

# %%
df_new['Rent'].unique()
# Out:
# array([  10000,   20000,   17000,    7500,    7000,    5000,   26000,
#          25000,    6500,    5500,    8500,   40000,    6000,   11000,
#           7900,    9000,    4000,    8000,    5300,   12500,   15000,
#          22000,   21000,    7200,   12000,    4600,   30000,    3500,
#          16000,   14500,    8200,    6700,   18000,   35000,  180000,
#          14000,    3900,    6300,   13000,    6800,    4700,    4500,
#          17500,    2200,    9500,   16500,   10500,   50000,    5200,
#          24000,    3000,    3200,    1500,    3800,    6200,    9900,
#          36125,   23000,    5146,   22500,   34000,    1800,    3700,
#           3300,   60000,   65000,   45000,   70000,   75000,  160000,
#         300000,  130000,   33000,   32000,   49000,   28000,   33500,
#          85000,  270000,  400000,  150000,  100000,   19411,  190000,
#          68000,  110000,   44000,   43000,   57000,   27000,   55000,
#          95000,   80000,   89000,   38000,  350000,  170000,  210000,
#          47000,  120000,   62000,   42000,   41000,   84500,  220000,
#         310000,   53000,  250000,   13500,   25500,   45002,   48000,
#         140000,  230000,  600000,   46000,   55100,  320000,   92500,
#          29999,  330000,   36000,   53500,   61000,  200000,   19000,
#          18500,   19500,   90000,   93000,   69999, 1000000,   33003,
#         450000,  280000,   56000,   83000,   39000,   15500,   51000,
#         260000,   43500,   77500,   59000,   72000,   52000,   51500,
#          98000,   23500, 1200000,   84000,  500000,    9400,   94000,
#          58000,   54500,   67000,  380000,   29500,   37000,   35500,
#          90100,   77000,  290000,  240000,   26500,   54000,   76000,
#          79500,   63000,   28500,  360000,   66000,  650000,  850000,
#          34999,   49500,   46700,   88000,   78000,   74999,   69000,
#          29000,   31000,  700000,  680000,   61500,   11400,   11500,
#          32900,    6900,   27500,    9750, 3500000,    8900,   21500,
#           9300,   26969,   42500,    4300,    4800,   17681,   13900,
#           7700,    4750,   17600,    9250,   14900,   20500,    2000,
#          17401,   44300,  530000,   20200,   31500,   22999,   12100,
#          24500,    7600,   11200,   34500,    5700,   23999,    5250,
#          47500,   18999,    4200,   15723,    6250,   37500,    6166,
#           9800,   19397,   27999,   10677,   32500,   23382,   19800,
#           1200,    5400,   12333,   21467,    5800])

# %%
df_new['Rent'].value_counts()
# Out:
# 15000    275
# 10000    248
# 12000    238
# 20000    175
# 8000     162
#         ...
# 4600       1
# 79500      1
# 76000      1
# 45002      1
# 5800       1
# Name: Rent, Length: 243, dtype: int64

# %%
fig2 = px.histogram(df_new, x = 'Rent', color = 'Rent')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="223c85b3-3a2a-48dc-8003-13591fa085dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("223c85b3-3a2a-48dc-8003-13591fa085dd")) {                    Plotly.newPlot(                        "223c85b3-3a2a-48dc-8003-13591fa085dd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Rent=%{x}<br>count=%{y}<extra></extra>","legendgroup":"10000","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"10000","offsetgroup":"10000","orientation":"v","showlegend":true,"x":[10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000,10000],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Rent=%{x}<br>count=%{y}<extra></extra>","legendgroup":"20000","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"20000","offsetgroup":"20000","orientation":"v","showlegend":true,"x":[20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000,20000],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Rent=%{x}<br>count=%{y}<extra></extra>","legendgroup":"17000","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"17000","offsetgroup":"17000","orientation":"v","showlegend":true,"x":[17000,17000,17000,17000,17000,17000,17000,17000,17000,17000,17000,17000,17000, ...

# %% [markdown]
# ### Menentukan standar & varians

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/House_Rent_Dataset.csv')
print(df)
# Standar variasi kolom Rent
df.loc[:, "Rent"].std()
# Varians kolom BHK
df.loc[:, "BHK"].var()
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4741              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner
#
# [4746 rows x 12 columns]
# 0.692649880527199

# %% [markdown]
# ### Menemukan nilai outliers

# %%
# Check outliers Rent

import pandas as pd
df = pd.read_csv('/content/sample_data/House_Rent_Dataset.csv')
# Hitung quartile 1
Q1 = df[["Rent"]].quantile(0.25)
# Hitung quartile 3
Q3 = df[["Rent"]].quantile(0.75)
# Hitung inter quartile range dan cetak ke console
IQR = Q3-Q1

# %%
# Check outliers Size

import pandas as pd
df = pd.read_csv('/content/sample_data/House_Rent_Dataset.csv')
# Hitung quartile 1
Q1 = df[["Size"]].quantile(0.25)
# Hitung quartile 3
Q3 = df[["Size"]].quantile(0.75)
# Hitung inter quartile range dan cetak ke console
IQR = Q3-Q1

# %% [markdown]
# ### Rename kolom Dataframe

# %%
# Rename columns

import pandas as pd
df = pd.read_csv('/content/sample_data/House_Rent_Dataset.csv')
# Ganti nama kolom tenant_preferred menjadi customer_preferred
df.rename(columns={"Tenant Preferred": "Customer Preferred"}, inplace=True)
print(df)
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  \
# 0                       Bandel    Kolkata       Unfurnished
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished
# 3                  Dumdum Park    Kolkata       Unfurnished
# 4                South Dum Dum    Kolkata       Unfurnished
# ...                        ...        ...               ...
# 4741              Bandam Kommu  Hyderabad    Semi-Furnished
# 4742      Manikonda, Hyderabad  Hyderabad    Semi-Furnished
# 4743      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished
# 4744                Gachibowli  Hyderabad    Semi-Furnished
# 4745           Suchitra Circle  Hyderabad       Unfurnished
#
#      Customer Preferred  Bathroom Point of Contact
# 0      Bachelors/Family         2    Contact Owner
# 1      Bachelors/Family         1    Contact Owner
# 2      Bachelors/Family         1    Contact Owner
# 3      Bachelors/Family         1    Contact Owner
# 4             Bachelors         1    Contact Owner
# ...                 ...       ...              ...
# 4741   Bachelors/Family         2    Contact Owner
# 4742   Bachelors/Family         3    Contact Owner
# 4743   Bachelors/Family         3    Contact Agent
# 4744             Family         2    Contact Agent
# 4745          Bachelors         2    Contact Owner
#
# [4746 rows x 12 columns]

# %% [markdown]
# ### Groupby menggunakan pandas

# %% [markdown]
# Kegunaan .groupby adalah mencari summary dari data frame dengan menggunakan aggregate dari kolom tertentu.

# %%
df["Bathroom"].groupby([df["BHK"]]).mean()
# Out:
# BHK
# 1    1.141388
# 2    1.835762
# 3    2.693989
# 4    3.994709
# 5    4.473684
# 6    5.250000
# Name: Bathroom, dtype: float64

# %%
df["Bathroom"].groupby([df["BHK"], df["Rent"]]).sum()
# Out:
# BHK  Rent
# 1    1500       1
#      1800       1
#      2200       1
#      3000       8
#      3200       1
#                ..
# 6    30000      5
#      35000      7
#      60000     13
#      80000      6
#      280000     5
# Name: Bathroom, Length: 488, dtype: int64

# %% [markdown]
# ### Sorting data

# %% [markdown]
# Sorting adalah sebuah metode mengurutkan data berdasarkan syarat kolom tertentu dan biasanya digunakan untuk melihat nilai maksimum dan minimum dari dataset. Library Pandas sendiri menyediakan fungsi sorting sebagai fundamental dari exploratory data analysis.

# %%
# Sorting data column Rent

df.sort_values(by="Rent")
# Out:
#        Posted On  BHK     Rent  Size            Floor    Area Type  \
# 4076  2022-05-31    3     1200  2100       1 out of 3  Carpet Area
# 285   2022-05-24    1     1500   200  Ground out of 2   Super Area
# 471   2022-05-12    1     1800   500  Ground out of 1   Super Area
# 2475  2022-06-22    2     2000    60       1 out of 1   Super Area
# 146   2022-06-05    2     2200   550       2 out of 3   Super Area
# ...          ...  ...      ...   ...              ...          ...
# 1459  2022-06-27    4   700000  3200     24 out of 24  Carpet Area
# 1329  2022-06-23    4   850000  3200       2 out of 4  Carpet Area
# 827   2022-05-18    4  1000000  3064     18 out of 45  Carpet Area
# 1001  2022-06-01    4  1200000  5000      4 out of 15  Carpet Area
# 1837  2022-06-08    3  3500000  2500       4 out of 4  Carpet Area
#
#                 Area Locality       City Furnishing Status Customer Preferred  \
# 4076            Uppal, NH 2 2  Hyderabad         Furnished   Bachelors/Family
# 285                Santoshpur    Kolkata    Semi-Furnished   Bachelors/Family
# 471               Shyam Bazar    Kolkata    Semi-Furnished   Bachelors/Family
# 2475                Ram Nagar      Delhi       Unfurnished   Bachelors/Family
# 146            Behala silpara    Kolkata         Furnished   Bachelors/Family
# ...                       ...        ...               ...                ...
# 1459  Lady Ratan Tower, Worli     Mumbai         Furnished   Bachelors/Family
# 1329             Breach Candy     Mumbai         Furnished   Bachelors/Family
# 827     Raheja Artesia, Worli     Mumbai    Semi-Furnished             Family
# 1001                     Juhu     Mumbai    Semi-Furnished   Bachelors/Family
# 1837             Marathahalli  Bangalore    Semi-Furnished          Bachelors
#
#       Bathroom Point of Contact
# 4076         3    Contact Owner
# 285          1    Contact Owner
# 471          1    Contact Owner
# 2475         1    Contact Owner
# 146          1    Contact Owner
# ...        ...              ...
# 1459         4    Contact Agent
# 1329         4    Contact Agent
# 827          4    Contact Agent
# 1001         4    Contact Agent
# 1837         3    Contact Agent
#
# [4746 rows x 12 columns]

# %%
# Sorting data column BHK

df.sort_values(by="BHK")
# Out:
#        Posted On  BHK    Rent  Size            Floor    Area Type  \
# 1539  2022-06-08    1   10000   600       3 out of 4   Super Area
# 1638  2022-05-31    1    8000   200  Ground out of 4   Super Area
# 820   2022-06-24    1   11000   200       4 out of 4   Super Area
# 1913  2022-06-04    1    5500   600  Ground out of 3   Super Area
# 817   2022-07-03    1   45000   450       5 out of 7  Carpet Area
# ...          ...  ...     ...   ...              ...          ...
# 3320  2022-06-28    6  280000  4500  Ground out of 1  Carpet Area
# 4350  2022-06-18    6   60000  2800  Ground out of 3   Super Area
# 4648  2022-07-06    6   80000  4500       1 out of 2   Super Area
# 4518  2022-05-12    6   35000  3400  Ground out of 2   Super Area
# 4696  2022-07-06    6   30000  4200  Ground out of 2   Super Area
#
#                       Area Locality       City Furnishing Status  \
# 1539             Btm Layout Stage 4  Bangalore    Semi-Furnished
# 1638               Old Airport Road  Bangalore    Semi-Furnished
# 820                    Parle Colony     Mumbai         Furnished
# 1913                     Rayasandra  Bangalore       Unfurnished
# 817             Lokhandwala Complex     Mumbai         Furnished
# ...                             ...        ...               ...
# 3320           Raja Annamalai Puram    Chennai    Semi-Furnished
# 4350               Boduppal, NH 2 2  Hyderabad         Furnished
# 4648  Kakateeya Nagar, Secunderabad  Hyderabad    Semi-Furnished
# 4518                       Rampally  Hyderabad       Unfurnished
# 4696                       Kuntloor  Hyderabad    Semi-Furnished
#
#      Customer Preferred  Bathroom Point of Contact
# 1539   Bachelors/Family         2    Contact Owner
# 1638   Bachelors/Family         1    Contact Owner
# 820    Bachelors/Family         1    Contact Owner
# 1913   Bachelors/Family         1    Contact Owner
# 817              Family         2    Contact Agent
# ...                 ...       ...              ...
# 3320          Bachelors         5    Contact Agent
# 4350   Bachelors/Family         7    Contact Owner
# 4648   Bachelors/Family         6    Contact Owner
# 4518   Bachelors/Family         7    Contact Owner
# 4696   Bachelors/Family         5    Contact Owner
#
# [4746 rows x 12 columns]

# %%
# Sorting data column Bathroom

df.sort_values(by="Bathroom")
# Out:
#        Posted On  BHK    Rent  Size            Floor    Area Type  \
# 2372  2022-05-23    2   14000   800  Ground out of 2   Super Area
# 1652  2022-05-23    1    7500   600       1 out of 2   Super Area
# 3316  2022-04-29    1    6500   550       2 out of 2   Super Area
# 1650  2022-05-10    1    8000   600  Ground out of 4   Super Area
# 3318  2022-05-03    1    7500   650  Ground out of 1   Super Area
# ...          ...  ...     ...   ...              ...          ...
# 1160  2022-06-03    4  300000  2308      9 out of 31  Carpet Area
# 4350  2022-06-18    6   60000  2800  Ground out of 3   Super Area
# 2846  2022-06-28    4  150000  4000       3 out of 3  Carpet Area
# 4518  2022-05-12    6   35000  3400  Ground out of 2   Super Area
# 4185  2022-06-06    1  200000  8000  Ground out of 4   Super Area
#
#                                 Area Locality       City Furnishing Status  \
# 2372                              Vijayanagar  Bangalore    Semi-Furnished
# 1652                             Bommanahalli  Bangalore    Semi-Furnished
# 3316                            Jawahar Nagar    Chennai       Unfurnished
# 1650                             Kamala Nagar  Bangalore    Semi-Furnished
# 3318                   Nemilichery, Chromepet    Chennai    Semi-Furnished
# ...                                       ...        ...               ...
# 1160  Windsor Grande Residences, Andheri West     Mumbai    Semi-Furnished
# 4350                         Boduppal, NH 2 2  Hyderabad         Furnished
# 2846                                 West End      Delhi    Semi-Furnished
# 4518                                 Rampally  Hyderabad       Unfurnished
# 4185      Beeramguda, Ramachandra Puram, NH 9  Hyderabad       Unfurnished
#
#      Customer Preferred  Bathroom Point of Contact
# 2372   Bachelors/Family         1    Contact Owner
# 1652   Bachelors/Family         1    Contact Owner
# 3316   Bachelors/Family         1    Contact Owner
# 1650   Bachelors/Family         1    Contact Owner
# 3318   Bachelors/Family         1    Contact Owner
# ...                 ...       ...              ...
# 1160   Bachelors/Family         6    Contact Agent
# 4350   Bachelors/Family         7    Contact Owner
# 2846          Bachelors         7    Contact Agent
# 4518   Bachelors/Family         7    Contact Owner
# 4185   Bachelors/Family        10    Contact Owner
#
# [4746 rows x 12 columns]
